# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_parquet("/content/drive/MyDrive/Praktikum/quantum_kernel_gpr_framework/experiments/scratch.parquet")

print(df.shape)
print(df.head())
# Out:
# (1, 16)
#              timestamp  n_qubits  n_layers  n_params  learning_rate  epochs  \
# 0  2026-06-08 13:51:44         2         3         8          0.001      10
#
#    N_train  N_test  noise_eps     phi       mse  runtime_sec  \
# 0       30      50        0.1  arccos  0.398578   137.372253
#
#    likelihood_noise  final_loss  parameter_movement  seed
# 0          0.683282    1.225779            0.024558    22

# %%
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           1 non-null      object
#  1   n_qubits            1 non-null      int64
#  2   n_layers            1 non-null      int64
#  3   n_params            1 non-null      int64
#  4   learning_rate       1 non-null      float64
#  5   epochs              1 non-null      int64
#  6   N_train             1 non-null      int64
#  7   N_test              1 non-null      int64
#  8   noise_eps           1 non-null      float64
#  9   phi                 1 non-null      object
#  10  mse                 1 non-null      float64
#  11  runtime_sec         1 non-null      float64
#  12  likelihood_noise    1 non-null      float64
#  13  final_loss          1 non-null      float64
#  14  parameter_movement  1 non-null      float64
# ...
